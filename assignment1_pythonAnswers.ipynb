# %% [markdown]
# # Data types in Python - Assignment 2
# Basics of Data Analysis  <br>
#                 Total Points 26 <br>
#                              ***To pass you need to get atleast 14 points***

# %% [markdown]
# Task 1: Create a string (name), an integer (num) and a floating point number (fnum). Assign your name to name, 25 to num and 56.78 to fnum. Print the output for all 3 variables. (6 points)

# %%
#name
name = "Pekka"
#num
num = 5
#fnum
fnum = 5.5
#print name
print(name)
#print num
print(num)
#print fnum
print(fnum)

# %% [markdown]
# Task 2: Use the capitalize() method to convert the first character of a string to uppercase letter. (1 point)

# %%
mystring = "this is getting interesting."
mycaptial_string = mystring.capitalize() #use capitalize method
print(mycaptial_string)  #print the capitalized string

# %% [markdown]
# Task 3: The find() method returns the index of first occurence of the substring if it is found and if it does not find it returns -1. Use find() method to complete the code below. (1 point)

# %%
text = "Python is an easy to learn language"
result = text.find("learn")#find learn
print(result) #print result

# %% [markdown]
# Task 4: It is possible to assign the same value to multiple variables at once in Python. Complete the code below. (1 point)

# %%
# create 3 variables a,b & c &
# assign 1 as value to all variables in the same statement
a = b = c = 1
print(a)  #print a
print(b)  #print b
print(c)  #print c

# %% [markdown]
# Task 5: Complete tasks as in the comment below (5 Points)

# %%
a = "I like python"
print("The length of the string is ", len(a)) # use the len method to print the length of the string
print("The first character of the string is", a[0]) # print the first character of the string
print("String in uppercase:", a.upper()) # print the string in uppercase letters

# %% [markdown]
# Task 6: Create a list named mylist and include 5 different data items. (4 points)

# %%
mylist = [20, "Data Analysis", 5.14, True, 'test'] # it should contain 5 different data items
print("Original List", mylist) # print the entire list
print("Second element:", mylist[1]) # print only the second element
#use append to add one more item to your list
mylist.append("Databases")
print("New List:", mylist) #print the entire list

# %% [markdown]
# Task 7: Tuple (3 points)

# %%
courses = ("Introduction to IoT & Cloud", "Python Basics for IoT", "Python Project")
print("Number of courses in the tuple:", len(courses)) #use len method to print the number of items(courses) in the tuple courses.
print("All items in the tuple courses:", courses) #print all items in the tuple courses
print("The third item in the tuple is", courses[2]) #print the third item in the tuple

# %% [markdown]
# Task 8: Dictionary (5 points)

# %%
#create a dictionary with the key as course, time and ects

#values as Python Basics, Autumn, 5
test = {
    "course": "Python Basics",
    "time": "Autumn",
    "ects": 5
}

print("Value of course:", test.get("course")) #use get method to print the value of the course

test["course"] = "Python Basics for IoT"  #change the course value to Python Basics for IoT

test["year"] = 2019 #add the key/value pair as year:2019 to the test dictionary
print("Updated Dictionary", test) #print the entire dictionary
